# %% [markdown]
# Visualisation des données

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
file = 'data_tp1_app.txt'
data = pd.read_csv('Archive/'+file,sep=' ', header=None, names=['label','x','y'])

# %%
plt.figure(figsize=(20,20))
for label in np.unique(data['label']):
    plt.scatter(data[data['label']==label]['x'],data[data['label']==label]['y'])
plt.legend(["app_{}".format(l) for l in np.unique(data['label'])])
plt.show()

# %%
data[data['label']==1]
# Out:
#     label          x         y
# 0       1  -6.315382  6.344938
# 1       1  -4.943573  7.821684
# 2       1  -8.920876  2.705258
# 3       1  -5.661533  7.425065
# 4       1  -5.918269  5.697313
# ..    ...        ...       ...
# 95      1  -7.349321  4.544704
# 96      1 -10.011338  3.986633
# 97      1  -8.265909  4.298196
# 98      1  -4.767163  7.536841
# 99      1  -3.940310  8.777248
#
# [100 rows x 3 columns]
